# %% [markdown]
# # How many resources are required to create the blueprints?
#
# I want to have a factory set up that will create a certain product, like miners. I want to be able to go to a factory, ask for a certain amount, then that amount is output to a chest (or logistics network???)
#
# If I know how many resources a certain blueprint requires, then I will know how many resources to generate/mine and also be able to multiply the resources by the number of blueprints.
#
# or just limit output to one stack in a chest, then it will alway refill that one slot?
#
#
# ## Train network
#
# rail
# locomotive
# cargo wagon
# barrels
#
# ## Train load/unload station
#
# (without defenses like walls and turrets)
#
# - 10 x blue inserters
# - 10 x green inserters
# - 18 x red belt
# - 10 x steel chest
# - 13 x rail
# - 4 x underground red belt
# - 1 x substation
# - 1 x train stop
#
# ### Rail
#
# - 1 x iron stick
# - 1 x steel plate
# - 1 x stone
#
#
# ## - Efficiency 2 module
# - 5 x red circuit
# - 4 x efficiency 1 module
# - 5 x blue circuit
#
# ### Efficiency 1 module
# - 5 x red circuit
# - 5 x green circuit
#
# Total:
# - (8 * 5) + (8 * (4 * 5)) = 200 red circuits
# - 8 * (4 * 5) = 160 green circuits
# - 8 * 5 = 40 blue circuits
#
# Eff2 modules need lots of resources so raw values are omitted from the below figures
#
#
# ## Mining blueprint
#
# - 4 x Electric mining drill
# - 8 x Efficiency module 2
# - 3 x red belt
# - 2 x underground red belt
# - 1 x medium electric pole
#
# ### - Electric mining drill
# - 3 x green circuit
# - 5 x iron gear
# - 10 x iron plate
#
# Total:
# - 4 * 3 = 12 green circuit
# - 4 * 5 = 20 iron gear
# - 4 * 10 = 40 iron plate
#
# ### - Red belt
# - 5 x iron gear
# - 1 x yellow belt
#
# #### Yellow belt
# - 1 x iron gear
# - 1 x iron plate
#
# Total:
# - 3 * (5 + 1) = 18 iron gears
# - 3 * 1 = 3 yellow belt
#
# ### - Underground red belt
# - 40 x iron gear
# - 2 x underground yellow belt
#
# #### Underground yellow belt
# - 10 x iron plate
# - 5 x yellow belt
#
# #### Yellow belt
# - 1 x iron gear
# - 1 x iron plate
#
# Total:
# - 40 iron gears
# - 10 iron plates
# - 5 yellow belts
#
#
# ### - Medium electric pole
# - 2 x copper plate
# - 4 x iron stick
# - 2 x steel plate
#
#
# ### Total Raw:
#
# without modules:
#
# - 12 green circuit
# - 78 iron gear
# - 58 iron plate
# - 2 copper plate
# - 4 iron stick
# - 2 steel plate
#
# ## Furnaces blueprint
#
# - 8 x electric furnace
# - 29 x red belt
# - 16 x eff2 module
# - 16 x blue inserter
# - 2 x underground red belt
# - 1 x substation
#
# ### Electric furnace
#
# - 5 x red circuit
# - 10 x steel plate
#
# Total:
# - 8 * 5 = 45 red circuits
# - 8 * 10 = 80 steel plates
#
# ### - Red belt
# - 5 x iron gear
# - 1 x yellow belt
#
# #### Yellow belt
# - 1 x iron gear
# - 1 x iron plate
#
# Total:
# - 3 * (5 + 1) = 18 iron gears
# - 3 * 1 = 3 yellow belt
#
# ### Blue inserter
# - 2 x green circuits
# - 1 x yellow inserter
# - 2 x iron plate
#
# #### Yellow inserter
# - 1 x green circuit
# - 1 x iron gear
# - 1 x iron plate
#
# Total:
# - 16 * (2 + 1) = 48 green circuits
# - 16 * 1 = 16 iron gears
# - 16 * (2 + 1) = 48 iron plates
#
# ### - Underground red belt
# - 40 x iron gear
# - 2 x underground yellow belt
#
# #### Underground yellow belt
# - 10 x iron plate
# - 5 x yellow belt
#
# #### Yellow belt
# - 1 x iron gear
# - 1 x iron plate
#
# Total:
# - 40 iron gears
# - 10 iron plates
# - 5 yellow belts
#
#
# ### Substation
# - 5 x red circuit
# - 5 x copper plate
# - 10 x steel plate
#
# ### Total Raw:
#
# 50 red circuits
# 20 steel plates
#
# 74 iron gears
#
#
# ## Solar power plant blueprint

# %% [markdown]
# # Factories
#
# - Mining blueprint
# - Furnaces blueprint
# - Solar power plant blueprint
# - Sulfuric acid
# - Efficiency 2 module
# - Assembling machine 2
# - Red belt
# - Underground red belt
# - Walls
# - Rails
# - Substations
# - Medium electricity pole
# - Big electricity pole
#
# ## Subfactories
#
#
# - Green circuits
# - Red circuits
# - Blue circuits
# -
# - Steel plate
# - Sulfur
# - Plastic
# -
# - Stone Bricks
# - Concrete
# - Walls
# - Rails
# -
# - Substations
# - Medium electricity pole
# - Big electricity pole
#
# ## Stone
#
# Harvested stone ore, split output in half. quarter to walls, quarter to rails, half to stone bricks (for furnaces, and to make concrete)

# %% [markdown]
# # Need to find out how to use circuit network to control how much output into chest

# %% [markdown]
# Main bus items
#
# - Copper plate
# - Iron plate
# - Green/Red/Blue circuits
# - Stone bricks
# - Sulfuric acid barrels

# %% [markdown]
# - One factory with main bus for creating circuits
# - One factory with main bus for creating blueprint items
# - One factory with main bus for creating sulfuric acid
# - One factory with main bus for creating stone bricks (some bricks going to blueprint factory, but the rest going to making walls and rails)

# %% [markdown]
# Stone is an important resource, and is glue for all other factories: walls, rails, stone brick flooring, furnaces, concrete (centrifuges, reactors, flooring)
